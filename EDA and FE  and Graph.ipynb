# %%
#import necessary library
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/chandravani/EDA-Practice/main/googleplaystore.csv")

# %%
#using head we can execute top 5 index
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#shape of googleplaystore.csv
data.shape
# Out:
# (10841, 13)

# %%
#using tail can see the last 5 index
data.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
#sample so any row in the csv file
data.sample()
# Out:
#        App   Category  Rating Reviews Size     Installs  Type Price  \
# 1627  Zara  LIFESTYLE     4.3   95904  33M  10,000,000+  Free     0
#
#      Content Rating     Genres   Last Updated Current Ver Android Ver
# 1627       Everyone  Lifestyle  July 30, 2018       4.1.0  4.1 and up

# %%
data.sample(4)
# Out:
#                                                     App Category  Rating  \
# 3053                        Tennis Temple - Live Scores   SPORTS     4.6
# 3008      Hole19: Golf GPS App, Rangefinder & Scorecard   SPORTS     4.4
# 8621  Free Poker Games : Downtown Casino - Texas Holdem     GAME     4.5
# 7545                                            CM Apps    TOOLS     3.8
#
#      Reviews                Size  Installs  Type Price Content Rating  Genres  \
# 3053    5305  Varies with device  100,000+  Free     0       Everyone  Sports
# 3008    6106  Varies with device  100,000+  Free     0       Everyone  Sports
# 8621    2032                 50M   50,000+  Free     0           Teen    Card
# 7545    3341                1.9M  100,000+  Free     0       Everyone   Tools
#
#         Last Updated         Current Ver         Android Ver
# 3053    May 18, 2018  Varies with device  Varies with device
# 3008  August 1, 2018  Varies with device  Varies with device
# ...

# %%
#using info can check the whether data is int or object
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#using describe can get the statistics value
data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
#In csv file there is only one float columns using T can show object also
data.describe(include = "all").T
# Out:
#                  count unique                 top   freq      mean       std  \
# App              10841   9660              ROBLOX      9       NaN       NaN
# Category         10841     34              FAMILY   1972       NaN       NaN
# Rating          9367.0    NaN                 NaN    NaN  4.193338  0.537431
# Reviews          10841   6002                   0    596       NaN       NaN
# Size             10841    462  Varies with device   1695       NaN       NaN
# Installs         10841     22          1,000,000+   1579       NaN       NaN
# Type             10840      3                Free  10039       NaN       NaN
# Price            10841     93                   0  10040       NaN       NaN
# Content Rating   10840      6            Everyone   8714       NaN       NaN
# Genres           10841    120               Tools    842       NaN       NaN
# Last Updated     10841   1378      August 3, 2018    326       NaN       NaN
# ...

# %%
#checking duplicated value (True or False)
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Length: 10841, dtype: bool

# %%
# showing duplicate rows
data[data.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
#only Reviews showing 
data["Reviews"]
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10841, dtype: object

# %%
#specific column
data["Reviews"].shape
# Out:
# (10841,)

# %%
#reviews column dtyped
data["Reviews"].dtype
# Out:
# dtype('O')

# %%
#In Review column whether str  is  numeric or not
data.Reviews.str.isnumeric()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 10836    True
# 10837    True
# 10838    True
# 10839    True
# 10840    True
# Name: Reviews, Length: 10841, dtype: bool

# %%
data[data.Reviews.str.isnumeric()].head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data[~data.Reviews.str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
datadrop = data

# %%
#using drop we can drop  only 10472 row
datadrop = datadrop.drop(datadrop.index[10472])

# %%
#checking shape
datadrop.shape
# Out:
# (10840, 13)

# %%
#original shape
data.shape
# Out:
# (10841, 13)

# %%
#review dtypes
datadrop["Reviews"].dtype
# Out:
# dtype('O')

# %%
datadrop["Reviews"] = datadrop["Reviews"].astype("int")

# %%
datadrop["Reviews"].dtype
# Out:
# dtype('int64')

# %%
datadrop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.2+ MB

# %%
# size column
datadrop["Size"]
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10840, dtype: object

# %%
datadrop["Size"].dtype
# Out:
# dtype('O')

# %%
datadrop["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
#replace M as 000
datadrop["Size"]=datadrop["Size"].str.replace("M","000")

# %%
datadrop["Size"]
# Out:
# 0                     19000
# 1                     14000
# 2                    8.7000
# 3                     25000
# 4                    2.8000
#                 ...
# 10836                 53000
# 10837                3.6000
# 10838                9.5000
# 10839    Varies with device
# 10840                 19000
# Name: Size, Length: 10840, dtype: object

# %%
datadrop["Size"]=datadrop["Size"].str.replace("k"," ")

# %%
datadrop["Size"]
# Out:
# 0                     19000
# 1                     14000
# 2                    8.7000
# 3                     25000
# 4                    2.8000
#                 ...
# 10836                 53000
# 10837                3.6000
# 10838                9.5000
# 10839    Varies with device
# 10840                 19000
# Name: Size, Length: 10840, dtype: object

# %%
import numpy as np
datadrop["Size"] = datadrop["Size"].str.replace("Varies with device", str(np.nan))

# %%
data["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
datadrop["Size"].dtype
# Out:
# dtype('O')

# %%
datadrop["Size"] = datadrop["Size"].astype("float")

# %%
datadrop["Size"].dtype
# Out:
# dtype('float64')

# %%
datadrop["Size"].head(4)
# Out:
# 0    19000.0
# 1    14000.0
# 2        8.7
# 3    25000.0
# Name: Size, dtype: float64

# %%
for i in datadrop["Size"]:
    if i < 10:
        datadrop["Size"]=datadrop["Size"].replace(i,i*1000)

# %%
datadrop["Size"]
# Out:
# 0        19000.0
# 1        14000.0
# 2         8700.0
# 3        25000.0
# 4         2800.0
#           ...
# 10836    53000.0
# 10837     3600.0
# 10838     9500.0
# 10839        NaN
# 10840    19000.0
# Name: Size, Length: 10840, dtype: float64

# %%
datadrop["Size"].head(40)
# Out:
# 0     19000.0
# 1     14000.0
# 2      8700.0
# 3     25000.0
# 4      2800.0
# 5      5600.0
# 6     19000.0
# 7     29000.0
# 8     33000.0
# 9      3100.0
# 10    28000.0
# 11    12000.0
# 12    20000.0
# 13    21000.0
# 14    37000.0
# 15     2700.0
# 16     5500.0
# 17    17000.0
# 18    39000.0
# 19    31000.0
# 20    14000.0
# 21    12000.0
# 22     4200.0
# 23     7000.0
# 24    23000.0
# 25     6000.0
# 26    25000.0
# 27     6100.0
# 28     4600.0
# 29     4200.0
# 30     9200.0
# 31     5200.0
# 32    11000.0
# 33    11000.0
# 34     4200.0
# 35     9200.0
# 36    24000.0
# 37        NaN
# 38    11000.0
# 39     9400.0
# Name: Size, dtype: float64

# %%
datadrop["Size"]/1000
# Out:
# 0        19.0
# 1        14.0
# 2         8.7
# 3        25.0
# 4         2.8
#          ...
# 10836    53.0
# 10837     3.6
# 10838     9.5
# 10839     NaN
# 10840    19.0
# Name: Size, Length: 10840, dtype: float64

# %%
datadrop["Size"].dtype
# Out:
# dtype('float64')

# %%
datadrop.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews     Size  Installs  Type Price Content Rating  \
# 0      159  19000.0   10,000+  Free     0       Everyone
# 1      967  14000.0  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
import numpy as np
def Process_Size(item):
    if str(item)[-1]=='M':
        res=float(str(item).replace('M',''))
        res=res*1000
        return str(res)
    elif str(item)[-1]=='k':
        res=str(item).replace('k','')
        return res
    else:
        return str(np.NaN)

# %%
datadrop.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
datadrop["Installs"].str.replace("+","")
# Out:
# <ipython-input-53-5710cdc37bb0>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   datadrop["Installs"].str.replace("+","")
# 0            10,000
# 1           500,000
# 2         5,000,000
# 3        50,000,000
# 4           100,000
#             ...
# 10836         5,000
# 10837           100
# 10838         1,000
# 10839         1,000
# 10840    10,000,000
# Name: Installs, Length: 10840, dtype: object

# %%
datadrop["Installs"].str.replace("+","")
# Out:
# <ipython-input-54-5710cdc37bb0>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   datadrop["Installs"].str.replace("+","")
# 0            10,000
# 1           500,000
# 2         5,000,000
# 3        50,000,000
# 4           100,000
#             ...
# 10836         5,000
# 10837           100
# 10838         1,000
# 10839         1,000
# 10840    10,000,000
# Name: Installs, Length: 10840, dtype: object

# %%
datadrop["Installs"].str

# %%
datadrop["Installs"].dtype
# Out:
# dtype('O')

# %%
datadrop["Installs"][0]
# Out:
# '10,000+'

# %%
datadrop["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
char_to_removes=["+",",","$"]
cols_to_clean=["Installs","Price"]
for item in char_to_removes:
    for col in cols_to_clean:
        datadrop[col]=datadrop[col].str.replace(item,"")
# Out:
# <ipython-input-59-4bfa68cc0f9a>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   datadrop[col]=datadrop[col].str.replace(item,"")

# %%
datadrop.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews     Size Installs  Type Price Content Rating  \
# 0      159  19000.0    10000  Free     0       Everyone
# 1      967  14000.0   500000  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
datadrop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.4+ MB

# %%
datadrop["Installs"]=datadrop["Installs"].astype("int")

# %%
datadrop["Price"]=datadrop["Price"].astype("float")

# %%
datadrop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.4+ MB

# %%
datadrop["Last Updated"]
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10836       July 25, 2017
# 10837        July 6, 2018
# 10838    January 20, 2017
# 10839    January 19, 2015
# 10840       July 25, 2018
# Name: Last Updated, Length: 10840, dtype: object

# %%
datadrop["Last Updated"].dtype
# Out:
# dtype('O')

# %%
datadrop["Last Updated"]=pd.to_datetime(datadrop["Last Updated"])

# %%
datadrop["Last Updated"]
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 10840, dtype: datetime64[ns]

# %%
#adding day in separte column
datadrop["day"]=datadrop["Last Updated"].dt.day

# %%
#adding month in separte column
datadrop["month"]=datadrop["Last Updated"].dt.month

# %%
#adding year in separte column
datadrop["year"]=datadrop["Last Updated"].dt.year

# %%
datadrop.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %%
datadrop.shape
# Out:
# (10840, 16)

# %%
datadrop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  day             10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  year            10840 non-null  int64
# ...

# %%
datadrop.describe().T
# Out:
#             count          mean           std     min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01     1.0     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06     0.0    38.0    2094.0
# Size       9145.0  2.150653e+04  2.259602e+04    10.0  4900.0   13000.0
# Installs  10840.0  1.546434e+07  8.502936e+07     0.0  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01     0.0     0.0       0.0
# day       10840.0  1.560904e+01  9.561621e+00     1.0     6.0      16.0
# month     10840.0  6.422325e+00  2.578388e+00     1.0     5.0       7.0
# year      10840.0  2.017400e+03  1.100914e+00  2010.0  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size        30000.0  1.000000e+05
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# day            24.0  3.100000e+01
# month           8.0  1.200000e+01
# year         2018.0  2.018000e+03

# %%
datadrop.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver  day  \
# 0               Art & Design   2018-01-07       1.0.0  4.0.3 and up    7
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0  4.0.3 and up   15
#
#    month  year
# 0      1  2018
# 1      1  2018

# %%
datadrop.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %%
datadrop[datadrop.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
datadrop[datadrop.duplicated("Reviews")]
# Out:
#                                           App             Category  Rating  \
# 4       Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN     4.3
# 57                 Extreme Rally Championship    AUTO_AND_VEHICLES     4.2
# 126              Skin Care and Natural Beauty               BEAUTY     NaN
# 134             Lady adviser (beauty, health)               BEAUTY     NaN
# 156    Offline: English to Tagalog Dictionary  BOOKS_AND_REFERENCE     4.7
# ...                                       ...                  ...     ...
# 10835                                FR Forms             BUSINESS     NaN
# 10836                        Sya9a Maroc - FR               FAMILY     4.5
# 10837        Fr. Mike Schmitz Audio Teachings               FAMILY     5.0
# 10838                  Parkinson Exercices FR              MEDICAL     NaN
# 10839           The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %%
data2=datadrop.drop_duplicates(subset=['App'],keep="first")

# %%
data2
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data2.shape
# Out:
# (9659, 16)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9659 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   datetime64[ns]
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     9657 non-null   object
#  13  day             9659 non-null   int64
#  14  month           9659 non-null   int64
#  15  year            9659 non-null   int64
# ...

# %%
numeric_features = [i for i in data2.columns if data2[i].dtype != 'O']

# %%
numeric_features
# Out:
# ['Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Price',
#  'Last Updated',
#  'day',
#  'month',
#  'year']

# %%
data2[numeric_features]
# Out:
#        Rating  Reviews     Size  Installs  Price Last Updated  day  month  \
# 0         4.1      159  19000.0     10000    0.0   2018-01-07    7      1
# 1         3.9      967  14000.0    500000    0.0   2018-01-15   15      1
# 2         4.7    87510   8700.0   5000000    0.0   2018-08-01    1      8
# 3         4.5   215644  25000.0  50000000    0.0   2018-06-08    8      6
# 4         4.3      967   2800.0    100000    0.0   2018-06-20   20      6
# ...       ...      ...      ...       ...    ...          ...  ...    ...
# 10836     4.5       38  53000.0      5000    0.0   2017-07-25   25      7
# 10837     5.0        4   3600.0       100    0.0   2018-07-06    6      7
# 10838     NaN        3   9500.0      1000    0.0   2017-01-20   20      1
# 10839     4.5      114      NaN      1000    0.0   2015-01-19   19      1
# 10840     4.5   398307  19000.0  10000000    0.0   2018-07-25   25      7
#
#        year
# 0      2018
# 1      2018
# 2      2018
# 3      2018
# ...

# %%
categorical_features = [i for i in data2.columns if data2[i].dtype == 'O']

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Current Ver',
#  'Android Ver']

# %%
data2[categorical_features]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data2.head(1)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#    Reviews     Size  Installs  Type  Price Content Rating        Genres  \
# 0      159  19000.0     10000  Free    0.0       Everyone  Art & Design
#
#   Last Updated Current Ver   Android Ver  day  month  year
# 0   2018-01-07       1.0.0  4.0.3 and up    7      1  2018

# %%
data2["Type"].value_counts(normalize=True)*100
# Out:
# Free    92.172292
# Paid     7.827708
# Name: Type, dtype: float64

# %%
for col in categorical_features:
    print(f"{col}:{data2[col].value_counts(normalize=True)*100}")
    print("=============================================")
# Out:
# App:Photo Editor & Candy Camera & Grid & ScrapBook    0.010353
# Tic Tac CK                                        0.010353
# INFAMY RO                                         0.010353
# CK Call NEW                                       0.010353
# Ck Coif                                           0.010353
#                                                     ...
# Bike Race Free - Top Motorcycle Racing Games      0.010353
# Dance School Stories - Dance Dreams Come True     0.010353
# 3D Bowling                                        0.010353
# Mind Games Pro                                    0.010353
# iHoroscope - 2018 Daily Horoscope & Astrology     0.010353
# Name: App, Length: 9659, dtype: float64
# ...
# Category:FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# PERSONALIZATION         3.892743
# PRODUCTIVITY            3.872036
# ...

# %%
#Importing libraries for graph
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
sns.countplot(x=data["Type"])
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
sns.countplot(x = data["Content Rating"])
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
# categorical columns
plt.figure(figsize=(10, 12))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=10, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Type', 'Content Rating']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=datadrop[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=30)
    plt.tight_layout()

# %%
numeric_features
# Out:
# ['Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Price',
#  'Last Updated',
#  'day',
#  'month',
#  'year']

# %%
sns.kdeplot(datadrop['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(datadrop["Reviews"])
# Out:
# <Axes: xlabel='Reviews', ylabel='Density'>

# %%
sns.displot(datadrop["Rating"])

# %%
plt.hist(datadrop["Rating"])
plt.show()

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=datadrop[numeric_features[i]],shade=True, color='blue')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
datadrop["Category"].value_counts().plot.pie(y=datadrop["Category"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Category'>

# %%
datadrop_cat=datadrop["Category"].value_counts()[:10]

# %%
category = pd.DataFrame(datadrop['Category'].value_counts())        #Dataframe of apps on the basis of category
category.rename(columns = {'Category':'Count'},inplace=True)

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=datadrop_cat, y ='Count',data = category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %%
#which category having largest number of installaion

# %%
type(data.groupby(['Category'])['Installs'].sum().sort_values(ascending=False))
# Out:
# pandas.core.series.Series

# %%
datadrop_cat_installs=datadrop.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).reset_index()

# %%
df1 = datadrop_cat_installs.head(10)

# %%
df1
# Out:
#              Category     Installs
# 0                GAME  35086024415
# 1       COMMUNICATION  32647276251
# 2        PRODUCTIVITY  14176091369
# 3              SOCIAL  14069867902
# 4               TOOLS  11452771915
# 5              FAMILY  10258263505
# 6         PHOTOGRAPHY  10088247655
# 7  NEWS_AND_MAGAZINES   7496317760
# 8    TRAVEL_AND_LOCAL   6868887146
# 9       VIDEO_PLAYERS   6222002720

# %%
sns.barplot(x="Installs",y="Category",data=df1)
# Out:
# <Axes: xlabel='Installs', ylabel='Category'>

# %%
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df1 )
ax.set_xlabel('No. of Installations in Billions')
ax.set_ylabel('')
ax.set_title("Most Popular Categories in Play Store", size = 20)
# Out:
# Text(0.5, 1.0, 'Most Popular Categories in Play Store')

# %%
 ### What are the Top 5 most installed Apps in Each popular Categories ??

# %%
#install--app--category

# %%
dfa=datadrop.groupby(['Category','App'])['Installs'].sum().reset_index()

# %%
dfa
# Out:
#             Category                                                App  \
# 0     ART_AND_DESIGN                           350 Diy Room Decor Ideas
# 1     ART_AND_DESIGN    3D Color Pixel by Number - Sandbox Art Coloring
# 2     ART_AND_DESIGN                            AJ Styles HD Wallpapers
# 3     ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 4     ART_AND_DESIGN                              Ai illustrator viewer
# ...              ...                                                ...
# 9739         WEATHER                                      Yahoo Weather
# 9740         WEATHER  Yahoo! Weather for SH Forecast for understandi...
# 9741         WEATHER                                     Yandex.Weather
# 9742         WEATHER                         weather - weather forecast
# 9743         WEATHER                     wetter.com - Weather and Radar
#
#       Installs
# 0        10000
# 1       100000
# 2         5000
# 3         1000
# 4       100000
# ...

# %%
dfa=dfa.sort_values('Installs',ascending=False)

# %%
dfa[dfa.Category=='GAME'][:5]
# Out:
#      Category               App    Installs
# 4852     GAME    Subway Surfers  6000000000
# 4245     GAME  Candy Crush Saga  3000000000
# 4881     GAME      Temple Run 2  3000000000
# 4707     GAME               Pou  1500000000
# 4659     GAME    My Talking Tom  1000000000

# %%
dfa[dfa.Category=='PRODUCTIVITY'][:5]
# Out:
#           Category              App    Installs
# 7507  PRODUCTIVITY     Google Drive  4000000000
# 7505  PRODUCTIVITY  Google Calendar  1500000000
# 7444  PRODUCTIVITY          Dropbox  1500000000
# 7552  PRODUCTIVITY   Microsoft Word  1500000000
# 7414  PRODUCTIVITY      Cloud Print   500000000

# %%
dfa[dfa.Category=='FAMILY'][:5]
# Out:
#      Category                App    Installs
# 2698   FAMILY  Google Play Games  1000000000
# 2149   FAMILY   Candy Crush Saga   500000000
# 3005   FAMILY     My Talking Tom   500000000
# 3135   FAMILY                Pou   500000000
# 3183   FAMILY             ROBLOX   400000000

# %%
apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ]
sns.set_context("poster")
sns.set_style("darkgrid")

plt.figure(figsize=(40,30))

for i,app in enumerate(apps):
    df2 = dfa[dfa.Category == app]
    df3 = df2.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data= df3,x= 'Installs' ,y='App' )
    plt.xlabel('Installation in Millions')
    plt.ylabel('')
    plt.title(app,size = 20)
    
plt.tight_layout()
plt.subplots_adjust(hspace= .3)
plt.show()

# %%
##### How many apps are there on Google Play Store which get 5 ratings??
#

# %%
datadrop.groupby(["App"])["Rating"].mean().sort_values(ascending=False).reset_index().shape
# Out:
# (9659, 2)

# %%
rating=datadrop.groupby(["App"])["Rating"].sum().sort_values(ascending=False).reset_index()

# %%
rating.Rating==5.0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9654    False
# 9655    False
# 9656    False
# 9657    False
# 9658    False
# Name: Rating, Length: 9659, dtype: bool

# %%
rating[rating.Rating==5.0]
# Out:
#                                                     App  Rating
# 788                                             BI News     5.0
# 789   FD Calculator (EMI, SIP, RD & Loan Eligilibility)     5.0
# 790                                    CJ's Coffee Cafe     5.0
# 791                                    CP Installer App     5.0
# 792                                        ADS-B Driver     5.0
# ...                                                 ...     ...
# 1052                                                 BV     5.0
# 1053               Food-Aw - Order Food Online in Aruba     5.0
# 1054                              Spine- The dating app     5.0
# 1055                    Speeding Joyride & Car Meet App     5.0
# 1056                              Nur təfsiri 1-ci cild     5.0
#
# [269 rows x 2 columns]

# %%
rating2 = datadrop.groupby(['Category','Installs', 'App'])['Rating'].sum().sort_values(ascending = False).reset_index()

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=datadrop,y="Category",x='Price')
# Out:
# <Axes: xlabel='Price', ylabel='Category'>

# %%
## Which Category app users are reviewing the most ??

# %%
datadrop.groupby(['Category','App'])["Reviews"].sum().reset_index()
# Out:
#             Category                                                App  \
# 0     ART_AND_DESIGN                           350 Diy Room Decor Ideas
# 1     ART_AND_DESIGN    3D Color Pixel by Number - Sandbox Art Coloring
# 2     ART_AND_DESIGN                            AJ Styles HD Wallpapers
# 3     ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 4     ART_AND_DESIGN                              Ai illustrator viewer
# ...              ...                                                ...
# 9739         WEATHER                                      Yahoo Weather
# 9740         WEATHER  Yahoo! Weather for SH Forecast for understandi...
# 9741         WEATHER                                     Yandex.Weather
# 9742         WEATHER                         weather - weather forecast
# 9743         WEATHER                     wetter.com - Weather and Radar
#
#       Reviews
# 0          27
# 1        1518
# 2          48
# 3          18
# 4         486
# ...

# %%
datadrop.groupby("Category").agg({"Installs":"sum","Reviews":"sum"}).reset_index()
# Out:
#                Category     Installs     Reviews
# 0        ART_AND_DESIGN    124338100     1714440
# 1     AUTO_AND_VEHICLES     53130211     1163666
# 2                BEAUTY     27197050      396240
# 3   BOOKS_AND_REFERENCE   1921469576    21959069
# 4              BUSINESS   1001914865    13954552
# 5                COMICS     56086150     3383276
# 6         COMMUNICATION  32647276251   815462260
# 7                DATING    264310807     7291278
# 8             EDUCATION    871452000    39595786
# 9         ENTERTAINMENT   2869160000    59178154
# 10               EVENTS     15973161      161018
# 11               FAMILY  10258263505   410226330
# 12              FINANCE    876648734    17550728
# 13       FOOD_AND_DRINK    273898751     8883330
# 14                 GAME  35086024415  1585422349
# 15   HEALTH_AND_FITNESS   1583072512    37893743
# 16       HOUSE_AND_HOME    168712461     3976385
# 17   LIBRARIES_AND_DEMO     62995910     1037118
# ...

# %%
datadrop.groupby('Type').agg({'Installs':sum}).plot.pie(y='Installs')
# Out:
# <Axes: ylabel='Installs'>

# %%
datadrop.value_counts('Type').plot.pie(y='Type')
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(1,2,figsize=(20,7))
datadrop.value_counts('Type').plot.pie(y='Type',startangle=90, explode=(0.2,0), title='Percentage of the Free App and Paid App', legend=False, autopct='%.2f', ax=ax[0])
ax[0].set(ylabel='Type of Apps')
datadrop.groupby('Type').agg({'Installs':sum}).plot.pie(y='Installs', startangle=90, explode=(0.2,0), title='Percentage of Installs Number for Free App and Paid App', legend=False, autopct='%.2f', ax=ax[1])
# Out:
# <Axes: title={'center': 'Percentage of Installs Number for Free App and Paid App'}, ylabel='Installs'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="Installs",y="Rating",data=datadrop)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="Category",y="Rating",data=datadrop)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
#### Which Category are of largest size ??

# %%
df=pd.DataFrame({"col1":[1,2,3,4,4,5,5,56,6,6,],"col2":[2,3,5,34,45,454,56,46,56,43]})

# %%
df["col2"][1]=2

# %%
df[df["col1"].duplicated()]
# Out:
#    col1  col2
# 4     4    45
# 6     5    56
# 9     6    43

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
plt.subplots(figsize=(20,10))
freq= pd.Series()
freq=datadrop['year'].value_counts()
freq.plot()
plt.xlabel("Dates")
plt.ylabel("Number of updates")
plt.title("Time series plot of Last Updates")
# Out:
# Text(0.5, 1.0, 'Time series plot of Last Updates')

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Rating',data = data,palette="Set1_r")
plt.xticks(rotation =90)
plt.title('Countplot for ratings')             
plt.show()

# %%
datadrop
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...
